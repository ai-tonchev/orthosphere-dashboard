# %%
# %run app.py
# Out:
# 2025-11-05 18:17:47,232 - BERTopic - WARNING: You are loading a BERTopic model without explicitly defining an embedding model. If you want to also load in an embedding model, make sure to use `BERTopic.load(my_model, embedding_model=my_embedding_model)`.
# loading topic model...
#         <iframe
#             width="100%"
#             height="650"
#             src="http://0.0.0.0:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
